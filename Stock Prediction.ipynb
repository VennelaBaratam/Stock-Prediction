# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('c:\\Users\\Vennela Baratam\\Downloads\\GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
# Assuming 'google_stock_data' is the DataFrame containing the stock data

plt.figure(figsize=(20, 7))

# First subplot
plt.subplot(1, 2, 1)
plt.plot(google_stock_data['open'], label='Open', color='green')
plt.xlabel('Date', size=15)
plt.ylabel('Price', size=15)
plt.legend()

# Second subplot
plt.subplot(1, 2, 2)
plt.plot(google_stock_data['close'], label='Close', color='red')
plt.xlabel('Date', size=15)
plt.ylabel('Price', size=15)
plt.legend()

plt.show()

# %%
#data preprocessing
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)
google_stock_data.shape
# Out:
# (1258, 2)

# %%
# creating training dataset
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %%
# creating LSTM MODEL

from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 14s 157ms/step - loss: 0.0055 - mean_absolute_error: 0.0530 - val_loss: 0.0127 - val_mean_absolute_error: 0.0966
# Epoch 2/80
# 30/30 [==============================] - 3s 84ms/step - loss: 7.2159e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0021 - val_mean_absolute_error: 0.0372
# Epoch 3/80
# 30/30 [==============================] - 3s 86ms/step - loss: 5.7838e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0018 - val_mean_absolute_error: 0.0346
# Epoch 4/80
# 30/30 [==============================] - 3s 85ms/step - loss: 5.5456e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 5/80
# 30/30 [==============================] - 3s 84ms/step - loss: 5.0588e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0032 - val_mean_absolute_error: 0.0456
# Epoch 6/80
# 30/30 [==============================] - 3s 85ms/step - loss: 4.7122e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0021 - val_mean_absolute_error: 0.0361
# Epoch 7/80
# 30/30 [==============================] - 3s 85ms/step - loss: 4.5096e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0024 - val_mean_absolute_error: 0.0387
# Epoch 8/80
# 30/30 [==============================] - 3s 84ms/step - loss: 4.1587e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0023 - val_mean_absolute_error: 0.0375
# Epoch 9/80
# 30/30 [==============================] - 3s 84ms/step - loss: 3.9902e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0025 - val_mean_absolute_error: 0.0399
# Epoch 10/80
# 30/30 [==============================] - 3s 84ms/step - loss: 3.8615e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0048 - val_mean_absolute_error: 0.0582
# Epoch 11/80
# 30/30 [==============================] - 3s 84ms/step - loss: 3.5060e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0040 - val_mean_absolute_error: 0.0515
# Epoch 12/80
# 30/30 [==============================] - 3s 89ms/step - loss: 3.3979e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0112 - val_mean_absolute_error: 0.0924
# Epoch 13/80
# 30/30 [==============================] - 3s 88ms/step - loss: 3.3505e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0080 - val_mean_absolute_error: 0.0749
# Epoch 14/80
# 30/30 [==============================] - 3s 89ms/step - loss: 3.3850e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0053 - val_mean_absolute_error: 0.0582
# Epoch 15/80
# 30/30 [==============================] - 3s 85ms/step - loss: 3.1847e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0057 - val_mean_absolute_error: 0.0602
# Epoch 16/80
# 30/30 [==============================] - 3s 85ms/step - loss: 3.3996e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0075 - val_mean_absolute_error: 0.0714
# Epoch 17/80
# 30/30 [==============================] - 3s 85ms/step - loss: 3.2168e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0077 - val_mean_absolute_error: 0.0727
# Epoch 18/80
# 30/30 [==============================] - 3s 84ms/step - loss: 3.3234e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0045 - val_mean_absolute_error: 0.0523
# Epoch 19/80
# 30/30 [==============================] - 3s 85ms/step - loss: 2.8343e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0080 - val_mean_absolute_error: 0.0732
# Epoch 20/80
# 30/30 [==============================] - 3s 86ms/step - loss: 3.2650e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0086 - val_mean_absolute_error: 0.0776
# Epoch 21/80
# 30/30 [==============================] - 3s 85ms/step - loss: 2.8556e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0063 - val_mean_absolute_error: 0.0644
# Epoch 22/80
# 30/30 [==============================] - 3s 88ms/step - loss: 3.0463e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0046 - val_mean_absolute_error: 0.0533
# Epoch 23/80
# 30/30 [==============================] - 3s 84ms/step - loss: 2.7685e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0067 - val_mean_absolute_error: 0.0658
# Epoch 24/80
# 30/30 [==============================] - 3s 84ms/step - loss: 2.6642e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0061 - val_mean_absolute_error: 0.0623
# Epoch 25/80
# 30/30 [==============================] - 3s 84ms/step - loss: 2.7570e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0024 - val_mean_absolute_error: 0.0367
# Epoch 26/80
# 30/30 [==============================] - 3s 85ms/step - loss: 2.6917e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0034 - val_mean_absolute_error: 0.0449
# Epoch 27/80
# 30/30 [==============================] - 3s 85ms/step - loss: 2.6207e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0038 - val_mean_absolute_error: 0.0475
# Epoch 28/80
# 30/30 [==============================] - 3s 84ms/step - loss: 2.6675e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0032 - val_mean_absolute_error: 0.0426
# Epoch 29/80
# 30/30 [==============================] - 3s 84ms/step - loss: 2.6129e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0047 - val_mean_absolute_error: 0.0547
# Epoch 30/80
# 30/30 [==============================] - 3s 90ms/step - loss: 3.3895e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0022 - val_mean_absolute_error: 0.0353
# Epoch 31/80
# 30/30 [==============================] - 3s 87ms/step - loss: 3.0951e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 32/80
# 30/30 [==============================] - 3s 91ms/step - loss: 2.3837e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0055 - val_mean_absolute_error: 0.0592
# Epoch 33/80
# 30/30 [==============================] - 3s 84ms/step - loss: 2.4179e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0050 - val_mean_absolute_error: 0.0552
# Epoch 34/80
# 30/30 [==============================] - 3s 87ms/step - loss: 2.2803e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0068 - val_mean_absolute_error: 0.0669
# Epoch 35/80
# 30/30 [==============================] - 3s 85ms/step - loss: 2.4085e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0074 - val_mean_absolute_error: 0.0717
# Epoch 36/80
# 30/30 [==============================] - 2s 83ms/step - loss: 2.3933e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0044 - val_mean_absolute_error: 0.0526
# Epoch 37/80
# 30/30 [==============================] - 2s 82ms/step - loss: 2.0723e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0045 - val_mean_absolute_error: 0.0532
# Epoch 38/80
# 30/30 [==============================] - 2s 83ms/step - loss: 2.3229e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0056 - val_mean_absolute_error: 0.0602
# Epoch 39/80
# 30/30 [==============================] - 2s 81ms/step - loss: 2.1694e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0060 - val_mean_absolute_error: 0.0631
# Epoch 40/80
# 30/30 [==============================] - 3s 85ms/step - loss: 2.2579e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0045 - val_mean_absolute_error: 0.0536
# Epoch 41/80
# 30/30 [==============================] - 2s 82ms/step - loss: 2.0512e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0017 - val_mean_absolute_error: 0.0306
# Epoch 42/80
# 30/30 [==============================] - 2s 82ms/step - loss: 2.0947e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0025 - val_mean_absolute_error: 0.0382
# Epoch 43/80
# 30/30 [==============================] - 2s 83ms/step - loss: 2.3431e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0018 - val_mean_absolute_error: 0.0315
# Epoch 44/80
# 30/30 [==============================] - 3s 85ms/step - loss: 2.5880e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0037 - val_mean_absolute_error: 0.0461
# Epoch 45/80
# 30/30 [==============================] - 2s 84ms/step - loss: 2.1299e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0037 - val_mean_absolute_error: 0.0477
# Epoch 46/80
# 30/30 [==============================] - 3s 88ms/step - loss: 1.9404e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0054 - val_mean_absolute_error: 0.0597
# Epoch 47/80
# 30/30 [==============================] - 3s 91ms/step - loss: 1.8569e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0034 - val_mean_absolute_error: 0.0441
# Epoch 48/80
# 30/30 [==============================] - 3s 88ms/step - loss: 2.0911e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0046 - val_mean_absolute_error: 0.0530
# Epoch 49/80
# 30/30 [==============================] - 3s 84ms/step - loss: 2.0709e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0059 - val_mean_absolute_error: 0.0624
# Epoch 50/80
# 30/30 [==============================] - 3s 86ms/step - loss: 1.9004e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0063 - val_mean_absolute_error: 0.0631
# Epoch 51/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.7803e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0069 - val_mean_absolute_error: 0.0682
# Epoch 52/80
# 30/30 [==============================] - 3s 85ms/step - loss: 1.9434e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0056 - val_mean_absolute_error: 0.0591
# Epoch 53/80
# 30/30 [==============================] - 3s 88ms/step - loss: 2.0125e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0077 - val_mean_absolute_error: 0.0728
# Epoch 54/80
# 30/30 [==============================] - 3s 85ms/step - loss: 1.6722e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0050 - val_mean_absolute_error: 0.0556
# Epoch 55/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.7941e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0036 - val_mean_absolute_error: 0.0431
# Epoch 56/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.8193e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0026 - val_mean_absolute_error: 0.0356
# Epoch 57/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.8213e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0072 - val_mean_absolute_error: 0.0695
# Epoch 58/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.5943e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0033 - val_mean_absolute_error: 0.0419
# Epoch 59/80
# 30/30 [==============================] - 2s 84ms/step - loss: 1.6961e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0056 - val_mean_absolute_error: 0.0597
# Epoch 60/80
# 30/30 [==============================] - 2s 84ms/step - loss: 1.6108e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0079 - val_mean_absolute_error: 0.0726
# Epoch 61/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.6831e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0069 - val_mean_absolute_error: 0.0672
# Epoch 62/80
# 30/30 [==============================] - 3s 89ms/step - loss: 1.5237e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0044 - val_mean_absolute_error: 0.0501
# Epoch 63/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.6172e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0045 - val_mean_absolute_error: 0.0530
# Epoch 64/80
# 30/30 [==============================] - 2s 84ms/step - loss: 1.5568e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0034 - val_mean_absolute_error: 0.0441
# Epoch 65/80
# 30/30 [==============================] - 3s 87ms/step - loss: 1.6380e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0035 - val_mean_absolute_error: 0.0454
# Epoch 66/80
# 30/30 [==============================] - 3s 87ms/step - loss: 1.5620e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0037 - val_mean_absolute_error: 0.0473
# Epoch 67/80
# 30/30 [==============================] - 3s 90ms/step - loss: 1.4414e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0047 - val_mean_absolute_error: 0.0546
# Epoch 68/80
# 30/30 [==============================] - 3s 88ms/step - loss: 1.5619e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0051 - val_mean_absolute_error: 0.0582
# Epoch 69/80
# 30/30 [==============================] - 3s 85ms/step - loss: 1.5222e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0033 - val_mean_absolute_error: 0.0438
# Epoch 70/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.4278e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0044 - val_mean_absolute_error: 0.0529
# Epoch 71/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.3256e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0049 - val_mean_absolute_error: 0.0560
# Epoch 72/80
# 30/30 [==============================] - 3s 87ms/step - loss: 1.3512e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0043 - val_mean_absolute_error: 0.0513
# Epoch 73/80
# 30/30 [==============================] - 3s 87ms/step - loss: 1.4116e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0027 - val_mean_absolute_error: 0.0377
# Epoch 74/80
# 30/30 [==============================] - 2s 83ms/step - loss: 1.5126e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0060 - val_mean_absolute_error: 0.0631
# Epoch 75/80
# 30/30 [==============================] - 3s 84ms/step - loss: 1.5352e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0033 - val_mean_absolute_error: 0.0449
# Epoch 76/80
# 30/30 [==============================] - 3s 91ms/step - loss: 1.3169e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 77/80
# 30/30 [==============================] - 3s 94ms/step - loss: 1.3395e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0033 - val_mean_absolute_error: 0.0443
# Epoch 78/80
# 30/30 [==============================] - 3s 109ms/step - loss: 1.4735e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0039 - val_mean_absolute_error: 0.0499
# Epoch 79/80
# 30/30 [==============================] - 3s 96ms/step - loss: 1.2946e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0049 - val_mean_absolute_error: 0.0570
# Epoch 80/80
# 30/30 [==============================] - 3s 95ms/step - loss: 1.3241e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0035 - val_mean_absolute_error: 0.0476

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 2s 29ms/step
# array([[0.47562343, 0.47952121],
#        [0.48174584, 0.4857124 ],
#        [0.48697817, 0.49094078],
#        [0.50278693, 0.5065027 ],
#        [0.5125066 , 0.5165001 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1552.7678, 1556.976 ],
#        [1564.1183, 1568.4503],
#        [1573.8186, 1578.1401],
#        [1603.1267, 1606.9817],
#        [1621.1462, 1625.5104]], dtype=float32)

# %%
# data visualizing and actual data
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1552.767822      1556.975952
# 2020-08-25  1582.07  1608.22     1564.118286      1568.450317
# 2020-08-26  1608.00  1652.38     1573.818604      1578.140137
# 2020-08-27  1653.68  1634.33     1603.126709      1606.981689
# 2020-08-28  1633.49  1644.41     1621.146240      1625.510376

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index 

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,
                        index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
# C:\Users\Vennela Baratam\AppData\Local\Temp\ipykernel_10748\2970346174.py:4: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# C:\Users\Vennela Baratam\AppData\Local\Temp\ipykernel_10748\2970346174.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2231.781738      2336.740234
# 2021-06-10  2494.01  2521.60     2240.175293      2347.654053
# 2021-06-11  2524.92  2513.93     2248.142334      2358.829834
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])
# Out:
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\Vennela Baratam\AppData\Local\Temp\ipykernel_10748\4155468105.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
# Out:
# C:\Users\Vennela Baratam\AppData\Local\Temp\ipykernel_10748\548185773.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fg.show()
